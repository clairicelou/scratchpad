# %%
! git clone https://github.com/ds4e/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 118 (delta 42), reused 31 (delta 30), pack-reused 65 (from 2)
# Receiving objects: 100% (118/118), 1.76 MiB | 8.32 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('./data/brazil_default.csv', encoding='latin1')
# Out:
# /tmp/ipykernel_602/3697957170.py:7: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/brazil_default.csv', encoding='latin1')

# %%
df.columns.to_list()
# Out:
# ['ID_CLIENT',
#  'CLERK_TYPE',
#  'PAYMENT_DAY',
#  'APPLICATION_SUBMISSION_TYPE',
#  'QUANT_ADDITIONAL_CARDS',
#  'POSTAL_ADDRESS_TYPE',
#  'SEX',
#  'MARITAL_STATUS',
#  'QUANT_DEPENDANTS',
#  'EDUCATION_LEVEL',
#  'STATE_OF_BIRTH',
#  'CITY_OF_BIRTH',
#  'NACIONALITY',
#  'RESIDENCIAL_STATE',
#  'RESIDENCIAL_CITY',
#  'RESIDENCIAL_BOROUGH',
#  'FLAG_RESIDENCIAL_PHONE',
#  'RESIDENCIAL_PHONE_AREA_CODE',
#  'RESIDENCE_TYPE',
#  'MONTHS_IN_RESIDENCE',
#  'FLAG_MOBILE_PHONE',
#  'FLAG_EMAIL',
#  'PERSONAL_MONTHLY_INCOME',
#  'OTHER_INCOMES',
#  'FLAG_VISA',
#  'FLAG_MASTERCARD',
#  'FLAG_DINERS',
#  'FLAG_AMERICAN_EXPRESS',
#  'FLAG_OTHER_CARDS',
#  'QUANT_BANKING_ACCOUNTS',
#  'QUANT_SPECIAL_BANKING_ACCOUNTS',
#  'PERSONAL_ASSETS_VALUE',
#  'QUANT_CARS',
#  'COMPANY',
#  'PROFESSIONAL_STATE',
#  'PROFESSIONAL_CITY',
#  'PROFESSIONAL_BOROUGH',
#  'FLAG_PROFESSIONAL_PHONE',
#  'PROFESSIONAL_PHONE_AREA_CODE',
#  'MONTHS_IN_THE_JOB',
#  'PROFESSION_CODE',
#  'OCCUPATION_TYPE',
# ...

# %%
vars = [
 'QUANT_DEPENDANTS',
 'MONTHS_IN_RESIDENCE',
 'FLAG_MOBILE_PHONE',
 'FLAG_EMAIL',
 'PERSONAL_MONTHLY_INCOME',
 'OTHER_INCOMES',
 'FLAG_VISA',
 'FLAG_MASTERCARD',
 'FLAG_DINERS',
 'FLAG_AMERICAN_EXPRESS',
 'FLAG_OTHER_CARDS',
 'QUANT_BANKING_ACCOUNTS',
 'QUANT_SPECIAL_BANKING_ACCOUNTS',
 'PERSONAL_ASSETS_VALUE',
 'QUANT_CARS',
 'MONTHS_IN_THE_JOB',
 'PROFESSION_CODE',
 'OCCUPATION_TYPE',
 'FLAG_CPF',
 'FLAG_INCOME_PROOF',
 'TARGET_LABEL_BAD=1']

gdf = df.loc[ :, vars ]

# %%
X.describe()
# Out:
#        QUANT_DEPENDANTS  MONTHS_IN_RESIDENCE    FLAG_EMAIL  \
# count      39170.000000         39170.000000  39170.000000
# mean           0.685754             9.527368      0.747613
# std            1.213641            10.636813      0.434388
# min            0.000000             0.000000      0.000000
# 25%            0.000000             1.000000      0.000000
# 50%            0.000000             5.000000      1.000000
# 75%            1.000000            15.000000      1.000000
# max           53.000000           228.000000      1.000000
#
#        PERSONAL_MONTHLY_INCOME  OTHER_INCOMES     FLAG_VISA  FLAG_MASTERCARD  \
# count             39170.000000   39170.000000  39170.000000     39170.000000
# mean                919.939174      40.036305      0.120347         0.105029
# std                8671.564052    1005.008805      0.325371         0.306595
# min                  60.000000       0.000000      0.000000         0.000000
# ...

# %%
y = gdf['TARGET_LABEL_BAD=1']
X = gdf.drop( ['FLAG_MOBILE_PHONE','TARGET_LABEL_BAD=1'], axis=1)

def maxmin(z):
  u = (z-min(z))/(max(z)-min(z))
  return u

U = X.apply(maxmin)

from sklearn.linear_model import LogisticRegression

reg = LogisticRegression(penalty=None)
reg = reg.fit(U,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_602/401711853.py in <cell line: 0>()
#      11
#      12 reg = LogisticRegression(penalty=None)
# ---> 13 reg = reg.fit(U,y)
#      14
#      15
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# ...

# %%
gdf.head()
# Out:
#    QUANT_DEPENDANTS  MONTHS_IN_RESIDENCE FLAG_MOBILE_PHONE  FLAG_EMAIL  \
# 0                 1                 15.0                 N           1
# 1                 0                  1.0                 N           1
# 4                 0                 12.0                 N           1
# 5                 0                  4.0                 N           1
# 6                 2                  1.0                 N           1
#
#    PERSONAL_MONTHLY_INCOME  OTHER_INCOMES  FLAG_VISA  FLAG_MASTERCARD  \
# 0                    900.0            0.0          1                1
# 1                    750.0            0.0          0                0
# 4                   1200.0            0.0          0                0
# 5                    500.0            0.0          0                0
# 6                    320.0            0.0          0                0
#
#    FLAG_DINERS  FLAG_AMERICAN_EXPRESS  ...  QUANT_BANKING_ACCOUNTS  \
# ...
